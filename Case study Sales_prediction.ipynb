# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Car_sales.csv')

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['__year_resale_value'])
# Out:
# c:\python38\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\python38\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([32., 46., 24.,  6.,  4.,  4.,  0.,  1.,  3.,  1.]),
#  array([ 5.16 , 11.399, 17.638, 23.877, 30.116, 36.355, 42.594, 48.833,
#         55.072, 61.311, 67.55 ]),
#  <a list of 10 Patch objects>)

# %%
df['__year_resale_value']= df['__year_resale_value'].fillna(df['__year_resale_value'].median())

# %%
plot=['Price_in_thousands','Fuel_efficiency','Power_perf_factor','Curb_weight']

# %%
plt.hist(df['Price_in_thousands'])
# Out:
# c:\python38\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\python38\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([30., 54., 33., 13., 14.,  3.,  2.,  2.,  2.,  2.]),
#  array([ 9.235 , 16.8615, 24.488 , 32.1145, 39.741 , 47.3675, 54.994 ,
#         62.6205, 70.247 , 77.8735, 85.5   ]),
#  <a list of 10 Patch objects>)

# %%
df.isna().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     2
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        3
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
df['Price_in_thousands']= df['Price_in_thousands'].fillna(df['Price_in_thousands'].median())

# %%
df['Engine_size']= df['Engine_size'].fillna(df['Engine_size'].median())

# %%
df['Horsepower']= df['Horsepower'].fillna(df['Horsepower'].median())

# %%
df['Wheelbase']= df['Wheelbase'].fillna(df['Wheelbase'].median())

# %%
df['Width']= df['Width'].fillna(df['Width'].median())

# %%
df['Length']= df['Length'].fillna(df['Length'].median())

# %%
df['Curb_weight']= df['Curb_weight'].fillna(df['Curb_weight'].median())

# %%
df['Fuel_capacity']= df['Fuel_capacity'].fillna(df['Fuel_capacity'].median())

# %%
df['Fuel_efficiency']= df['Fuel_efficiency'].fillna(df['Fuel_efficiency'].median())

# %%
df['Power_perf_factor']= df['Power_perf_factor'].fillna(df['Power_perf_factor'].median())

# %%
df.isna().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# FPower_perf_factor     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
col=df.columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in col:
    if df[i].dtype == object:
        df[i]=le.fit_transform(df[i])
    else:
        pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    int32
#  1   Model                157 non-null    int32
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    int32
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    int32
# ...

# %%
df.drop(['FPower_perf_factor'], axis =1 ,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    int32
#  1   Model                157 non-null    int32
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    int32
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    int32
# ...

# %%
df['Latest_Launch']= pd.to_datetime(df['Latest_Launch'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    int32
#  1   Model                157 non-null    int32
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    int32
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
df.set_index('Latest_Launch')
# Out:
#                                Manufacturer  Model  Sales_in_thousands  \
# Latest_Launch
# 1970-01-01 00:00:00.000000047             0     79              16.919
# 1970-01-01 00:00:00.000000093             0    143              39.384
# 1970-01-01 00:00:00.000000009             0     25              14.114
# 1970-01-01 00:00:00.000000052             0    115               8.588
# 1970-01-01 00:00:00.000000020             1      8              20.397
# ...                                     ...    ...                 ...
# 1970-01-01 00:00:00.000000124            29    148               3.545
# 1970-01-01 00:00:00.000000026            29    125              15.245
# 1970-01-01 00:00:00.000000089            29    149              17.531
# 1970-01-01 00:00:00.000000071            29     24               3.493
# 1970-01-01 00:00:00.000000022            29    126              18.969
#
#                                __year_resale_value  Vehicle_type  \
# Latest_Launch
# ...

# %%
Y=df['Sales_in_thousands']
X = df.drop(['Sales_in_thousands', 'Latest_Launch'] , axis =1)

# %%
X
# Out:
#      Manufacturer  Model  __year_resale_value  Vehicle_type  \
# 0               0     79               16.360             1
# 1               0    143               19.875             1
# 2               0     25               18.225             1
# 3               0    115               29.725             1
# 4               1      8               22.255             1
# ..            ...    ...                  ...           ...
# 152            29    148               14.180             1
# 153            29    125               14.180             1
# 154            29    149               14.180             1
# 155            29     24               14.180             1
# 156            29    126               14.180             1
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.500          1.8       140.0      101.2   67.3   172.4
# 1                28.400          3.2       225.0      108.1   70.3   192.9
# ...

# %%
import statsmodels.api as sm

# %%
X_con =sm.add_constant(X)

# %%
X_con
# Out:
#      const  Manufacturer  Model  __year_resale_value  Vehicle_type  \
# 0      1.0             0     79               16.360             1
# 1      1.0             0    143               19.875             1
# 2      1.0             0     25               18.225             1
# 3      1.0             0    115               29.725             1
# 4      1.0             1      8               22.255             1
# ..     ...           ...    ...                  ...           ...
# 152    1.0            29    148               14.180             1
# 153    1.0            29    125               14.180             1
# 154    1.0            29    149               14.180             1
# 155    1.0            29     24               14.180             1
# 156    1.0            29    126               14.180             1
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.500          1.8       140.0      101.2   67.3   172.4
# ...

# %%
model=sm.OLS(Y,X_con).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     5.518
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           2.15e-08
# Time:                        16:59:52   Log-Likelihood:                -850.70
# No. Observations:                 157   AIC:                             1731.
# Df Residuals:                     142   BIC:                             1777.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
X1=X_con.drop(['Fuel_efficiency'], axis =1)
model1=sm.OLS(Y,X1).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     5.979
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           8.64e-09
# Time:                        17:06:44   Log-Likelihood:                -850.73
# No. Observations:                 157   AIC:                             1729.
# Df Residuals:                     143   BIC:                             1772.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
X2= X1.drop(['__year_resale_value'] , axis=1)
model2 = sm.OLS(Y,X2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     6.506
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           3.44e-09
# Time:                        17:08:53   Log-Likelihood:                -850.80
# No. Observations:                 157   AIC:                             1728.
# Df Residuals:                     144   BIC:                             1767.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
X3=X2.drop(['Price_in_thousands'], axis=1)
model4= sm.OLS(Y,X3).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.302
# Method:                 Least Squares   F-statistic:                     7.138
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           1.28e-09
# Time:                        17:13:06   Log-Likelihood:                -850.83
# No. Observations:                 157   AIC:                             1726.
# Df Residuals:                     145   BIC:                             1762.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
X4= X3.drop(['Power_perf_factor'] , axis=1)
model5= sm.OLS(Y,X4).fit()
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     7.887
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           4.60e-10
# Time:                        17:15:41   Log-Likelihood:                -850.90
# No. Observations:                 157   AIC:                             1724.
# Df Residuals:                     146   BIC:                             1757.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X5=X4.drop(['Width'], axis=1)
model6 = sm.OLS(Y,X5).fit()
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     8.786
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           1.64e-10
# Time:                        17:17:23   Log-Likelihood:                -851.01
# No. Observations:                 157   AIC:                             1722.
# Df Residuals:                     147   BIC:                             1753.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X6=X5.drop(['Fuel_capacity'] , axis=1)
model7= sm.OLS(Y,X6).fit()
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     9.904
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           5.55e-11
# Time:                        17:18:53   Log-Likelihood:                -851.14
# No. Observations:                 157   AIC:                             1720.
# Df Residuals:                     148   BIC:                             1748.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X7=X6.drop(['Manufacturer'] , axis =1)
model8= sm.OLS(Y,X7).fit()
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           2.12e-11
# Time:                        17:21:11   Log-Likelihood:                -851.49
# No. Observations:                 157   AIC:                             1719.
# Df Residuals:                     149   BIC:                             1743.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X8=X7.drop(['Length'], axis=1)
model9= sm.OLS(Y,X8).fit()
model9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     12.98
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           8.60e-12
# Time:                        17:22:31   Log-Likelihood:                -851.97
# No. Observations:                 157   AIC:                             1718.
# Df Residuals:                     150   BIC:                             1739.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X9=X8.drop(['Model'], axis=1)
model10= sm.OLS(Y,X9).fit()
model10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     14.77
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):           8.76e-12
# Time:                        17:25:25   Log-Likelihood:                -853.55
# No. Observations:                 157   AIC:                             1719.
# Df Residuals:                     151   BIC:                             1737.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF']= [variance_inflation_factor(X9.values, i) for i in range(X9.shape[1])]
vif["features"] = X9.columns
vif.round(1)
# Out:
#      VIF      features
# 0  279.5         const
# 1    1.8  Vehicle_type
# 2    5.2   Engine_size
# 3    4.3    Horsepower
# 4    1.8     Wheelbase
# 5    4.1   Curb_weight

# %%
X10=X9.drop(['const'],axis=1)

# %%
X10.columns
# Out:
# Index(['Vehicle_type', 'Engine_size', 'Horsepower', 'Wheelbase',
#        'Curb_weight'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X10,Y)
# Out:
# LinearRegression()

# %%
prd=lr.predict(X10)

# %%
prd
# Out:
# array([ 42.43264661,  23.70793447,  20.84529833,  52.1407424 ,
#         22.35885453,  23.9590006 ,  11.97456326,  46.09546892,
#         42.76292105,  45.70333394,  59.75959667,  38.10586718,
#         65.04913027,  68.66539848,  49.63373232,  73.00232476,
#         23.1969939 ,  11.83298052,  41.5034163 ,  80.03031814,
#         71.87158233,  54.94078808,  75.68043786,  24.24999124,
#         43.71713008,  47.91818873,  67.015767  ,  72.75103273,
#         45.41271993,  31.84923134,  47.54481188,  69.01288751,
#         39.1896072 ,  77.77559781,  39.01025586,  75.39732289,
#         50.67369241,  57.68410942,  44.28695174,  14.62117686,
#        204.387173  ,  66.70139369, 146.72913469, 192.15512136,
#        100.20832716,  90.97605475,  61.62177527,  48.18048737,
#         66.8251688 ,  64.59768471,  79.19580568,  90.20212292,
#         83.17015933, 131.86751619,  66.28593576, 157.02088168,
#        202.8196394 ,  81.0875594 ,  70.75982419,  51.06862246,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(Y, prd)
# Out:
# 0.3284064266274054
